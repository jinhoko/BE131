# %%
from Bio import Phylo

tree = Phylo.read('tree.nwk', 'newick')
#Phylo.draw(tree)
Phylo.draw_ascii(tree)
# Out:
#  , rh.61
#  |
#  |_ rh.58
#  |
#  |                               , pi.2
#  |           ____________________|
#  |          |                    , pi.3
#  |          |                    |
#  |          |                    | pi.1
#  |          |
#  |          |           , rh.10
#  |        __|          _|
#  |       |  |         | , bb.1
#  |       |  |         | |
#  |       |  |  _______| | bb.2
#  |       |  | |       |
#  |       |  | |       | _ hu.17
#  |       |  | |       ||
#  |       |  |_|        | hu.6
#  |       |    |
#  |       |    |    _______ rh.2
#  |       |    |   |
#  |       |    |___|          __ rh.40
#  |       |        |         |
#  |       |        |_________|, hu.67
#  |       |                  ||
#  |       |                  |, hu.37
#  |       |                   |
#  |       |                   , hu.40
#  |       |                   |
#  |       |                   | hu.66
#  |       |                   |
#  |       |                   , hu.41
# ...
